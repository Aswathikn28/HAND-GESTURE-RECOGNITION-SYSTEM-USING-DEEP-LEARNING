# %%
#FOUND THE CROPPED PORTION OF BOUNDING BOX FOR ENTIRE DATASET

import os
import cv2
import mediapipe

# Initialize MediaPipe Hands
hands = mediapipe.solutions.hands.Hands(static_image_mode=True, max_num_hands=1, min_detection_confidence=0.5)

# Path to the root directory of the dataset
root_dataset_path = 'D:/OUHANDS1/ARRANGEDTRAIN/'

# List of classes
classes = ['A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'J', 'K']

# List of possible suffixes
suffixes = ['xla', 'zba', 'rsa', 'sta', 'vka', 'vkb', 'msb', 'psa', 'rha', 'mmc', 'mmd', 'msa', 'mkb', 'mma', 'mmb', 'jhb', 'jya', 'mka', 'ima', 'jha']

# Bounding box padding
padding = 30

# Output directory for cropped images
output_crop_directory = 'D:\PROJECT-OUHANDS\CROPPEDBOUNDBOX'

# Loop through each class
for class_label in classes:
    # Loop through each image in the class
    for image_number in range(1, 201):  # Assuming images are named from 1 to 200
        # Iterate over all suffixes for each image
        for suffix in suffixes:
            # Construct the path to the image
            image_path = os.path.join(root_dataset_path, class_label, f'{class_label}-{suffix}-{str(image_number).zfill(4)}.png').replace(os.sep, '/')

            # Read the input image
            image = cv2.imread(image_path)

            # Check if the image is loaded successfully
            if image is not None:
                # Process the image and get hand landmarks
                image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                results = hands.process(image_rgb)

                # Check if landmarks are found
                if results.multi_hand_landmarks:
                    for landmarks in results.multi_hand_landmarks:
                        # Initialize bounding box coordinates
                        min_x, min_y = float('inf'), float('inf')
                        max_x, max_y = float('-inf'), float('-inf')

                        for landmark in landmarks.landmark:
                            # Each landmark is a 3D point, where x, y, and z are normalized to [0.0, 1.0]
                            x, y, z = landmark.x, landmark.y, landmark.z
                            # Convert normalized coordinates to pixel coordinates
                            h, w, c = image.shape
                            x_pixel, y_pixel = int(x * w), int(y * h)

                            # Update bounding box coordinates
                            min_x = min(min_x, x_pixel)
                            min_y = min(min_y, y_pixel)
                            max_x = max(max_x, x_pixel)
                            max_y = max(max_y, y_pixel)

                        # Increase the size of the bounding box by padding pixels on all sides
                        min_x -= padding
                        min_y -= padding
                        max_x += padding
                        max_y += padding

                        # Crop the image based on the bounding box
                        cropped_image = image[min_y:max_y, min_x:max_x]

                        # Check if the cropped image is not empty before saving
                        if not cropped_image.size == 0:
                            # Save the cropped image to the output directory
                            output_file_path = os.path.join(output_crop_directory, class_label, f'{class_label}-{suffix}-{str(image_number).zfill(4)}_cropped.png').replace(os.sep, '/')
                            os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
                            cv2.imwrite(output_file_path, cropped_image)

                            print(f"Cropped image saved to: {output_file_path}")

print("Cropping completed for the entire dataset.")
# Out:
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rha-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-xla-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-zba-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-rsa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-sta-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-vkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-psa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmc-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmd-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-msa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mma-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mmb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jhb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jya-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-mka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-ima-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/A/A-jha-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mma-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-xla-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-zba-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rsa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-sta-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-vkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-psa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-rha-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmc-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmd-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-msa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mmb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jhb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jya-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-mka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-ima-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/B/B-jha-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-xla-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jya-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-zba-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-rsa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-sta-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-vkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-psa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmc-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmd-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-msa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mma-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mmb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jhb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-mka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-ima-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/C/C-jha-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-xla-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-zba-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-rsa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-sta-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-vka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-vkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-msb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-psa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-rha-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/D/D-mmc-0001_cropped.png
# ...
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/J/J-jha-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0001_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rha-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0002_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rha-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0003_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rha-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0004_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0005_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rha-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0006_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0007_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0008_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0009_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-xla-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-zba-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-rsa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-sta-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-vkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-psa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmc-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmd-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-msa-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mkb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mma-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mmb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jhb-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jya-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-mka-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-ima-0010_cropped.png
# Cropped image saved to: D:/PROJECT-OUHANDS/CROPPEDBOUNDBOX/K/K-jha-0010_cropped.png
# Cropping completed for the entire dataset.
